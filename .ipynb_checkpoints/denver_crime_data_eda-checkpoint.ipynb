# %% [markdown]
# # Denver Crime Data
#
# The city of Denver, CO publishes its crime data to their open data catalogue: [crime](https://www.denvergov.org/opendata/dataset/city-and-county-of-denver-crime).
#
# I want to explore what the most often reported crimes are, what areas have the most crime (total, per capita, per area), trends in time of day, time of month, time of year. Explore outliers and if they are related to specific events. What is the probability that crime is increasing year over year? Can we predict where crimes will occur?
#
# At minimum, plot time series incidents by area, by type, by year; analysis of most common crimes committed, levels of activity in each district in Denver; bayesian analysis of the probability that crime is increasing year-over-year; and model to predict likelihood of a crime taking place in a given area or at a given time during the day.
#
# This dataset is a snapshot of the database as of 02/11/2019. Future updates will
#
# ### About Crime Data
# The Denver Police Department strives to make crime data as accurate as possible, but there is no avoiding the introduction of errors into this process, which relies on data furnished by many people and that cannot always be verified. Data on this site are updated Monday through Friday, adding new incidents and updating existing data with information gathered through the investigative process.
#
# Not surprisingly, crime data become more accurate over time, as new incidents are reported and more information comes to light during investigations.
#
# Crimes that occurred at least 30 days ago tend to be the most accurate, although records are returned for incidents that happened yesterday. This dynamic nature of crime data means that content provided here today will probably differ from content provided a week from now. Likewise, content provided on this site will probably differ somewhat from crime statistics published elsewhere by the City and County of Denver, even though they draw from the same database.
#
# ### Withheld Data
# In accordance with legal restrictions against identifying sexual assault and child abuse victims and juvenile perpetrators, victims, and witnesses of certain crimes, this site includes the following precautionary measures: (a) Addresses of sexual assaults are not included. (b) Child abuse cases, and other crimes which by their nature involve juveniles, or which the reports indicate involve juveniles as victims, suspects, or witnesses, are not reported at all.
#
# Crimes that are initially reported, but that are later determined not to have occurred, are called "unfounded" offenses. These incidents are excluded once they have been designated as unfounded.
#
# ### About Crime Locations
# Crime locations reflect the approximate locations of crimes but are not mapped to actual property parcels. Certain crimes may not appear on maps if there is insufficient detail to establish a specific, mappable location.

# %% [markdown]
# ## Importing Libraries and loading the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime,timedelta

# %%
figs_save = {}

# %%
df_ = pd.read_csv('data/crime.csv')
df_.head()
# Out:
#    INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0   2016376978   2016376978521300          5213                       0
# 1  20186000994  20186000994239900          2399                       0
# 2  20166003953  20166003953230500          2305                       0
# 3    201872333    201872333239900          2399                       0
# 4   2017411405   2017411405230300          2303                       0
#
#                 OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# 0  weapon-unlawful-discharge-of          all-other-crimes
# 1                   theft-other                   larceny
# 2      theft-items-from-vehicle  theft-from-motor-vehicle
# 3                   theft-other                   larceny
# 4                theft-shoplift                   larceny
#
#     FIRST_OCCURRENCE_DATE   LAST_OCCURRENCE_DATE          REPORTED_DATE  \
# 0   6/15/2016 11:31:00 PM                    NaN  6/15/2016 11:31:00 PM
# 1  10/11/2017 12:30:00 PM  10/11/2017 4:55:00 PM   1/29/2018 5:53:00 PM
# 2     3/4/2016 8:00:00 PM   4/25/2016 8:00:00 AM   4/26/2016 9:02:00 PM
# 3    1/30/2018 7:20:00 PM                    NaN  1/30/2018 10:29:00 PM
# 4    6/22/2017 8:53:00 PM                    NaN   6/23/2017 4:09:00 PM
#
#       INCIDENT_ADDRESS      GEO_X      GEO_Y     GEO_LON    GEO_LAT  \
# 0                  NaN  3193983.0  1707251.0 -104.809881  39.773188
# 1                  NaN  3201943.0  1711852.0 -104.781434  39.785649
# 2  2932 S JOSEPHINE ST  3152762.0  1667011.0 -104.957381  39.663490
# 3  705 S COLORADO BLVD  3157162.0  1681320.0 -104.941440  39.702698
# 4       2810 E 1ST AVE  3153211.0  1686545.0 -104.955370  39.717107
#
#    DISTRICT_ID  PRECINCT_ID             NEIGHBORHOOD_ID  IS_CRIME  IS_TRAFFIC
# 0            5          521                   montbello         1           0
# 1            5          522  gateway-green-valley-ranch         1           0
# 2            3          314                   wellshire         1           0
# 3            3          312                     belcaro         1           0
# 4            3          311                cherry-creek         1           0

# %%
df_offense_codes = pd.read_csv('data/offense_codes.csv')
df_offense_codes.head()
# Out:
#    OFFENSE_CODE  OFFENSE_CODE_EXTENSION                 OFFENSE_TYPE_ID  \
# 0          2804                       1      stolen-property-possession
# 1          2804                       2  fraud-possess-financial-device
# 2          2901                       0                damaged-prop-bus
# 3          2902                       0       criminal-mischief-private
# 4          2903                       0        criminal-mischief-public
#
#                        OFFENSE_TYPE_NAME OFFENSE_CATEGORY_ID  \
# 0          Possession of stolen property    all-other-crimes
# 1       Possession of a financial device    all-other-crimes
# 2              Damaged business property     public-disorder
# 3  Criminal mischief to private property     public-disorder
# 4   Criminal mischief to public property     public-disorder
#
#   OFFENSE_CATEGORY_NAME  IS_CRIME  IS_TRAFFIC
# 0      All Other Crimes         1           0
# 1      All Other Crimes         1           0
# 2       Public Disorder         1           0
# 3       Public Disorder         1           0
# 4       Public Disorder         1           0

# %% [markdown]
# ### Changing all dates to python datetime object for easier manipulation

# %%
df_['FIRST_OCCURRENCE_DATE'] = pd.to_datetime(df_['FIRST_OCCURRENCE_DATE'], infer_datetime_format=True)
df_['LAST_OCCURRENCE_DATE'] = pd.to_datetime(df_['LAST_OCCURRENCE_DATE'], infer_datetime_format=True)
df_['REPORTED_DATE'] = pd.to_datetime(df_['REPORTED_DATE'], infer_datetime_format=True)

# %%
df_.head()
# Out:
#    INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0   2016376978   2016376978521300          5213                       0
# 1  20186000994  20186000994239900          2399                       0
# 2  20166003953  20166003953230500          2305                       0
# 3    201872333    201872333239900          2399                       0
# 4   2017411405   2017411405230300          2303                       0
#
#                 OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# 0  weapon-unlawful-discharge-of          all-other-crimes
# 1                   theft-other                   larceny
# 2      theft-items-from-vehicle  theft-from-motor-vehicle
# 3                   theft-other                   larceny
# 4                theft-shoplift                   larceny
#
#   FIRST_OCCURRENCE_DATE LAST_OCCURRENCE_DATE       REPORTED_DATE  \
# 0   2016-06-15 23:31:00                  NaT 2016-06-15 23:31:00
# 1   2017-10-11 12:30:00  2017-10-11 16:55:00 2018-01-29 17:53:00
# 2   2016-03-04 20:00:00  2016-04-25 08:00:00 2016-04-26 21:02:00
# 3   2018-01-30 19:20:00                  NaT 2018-01-30 22:29:00
# 4   2017-06-22 20:53:00                  NaT 2017-06-23 16:09:00
#
#       INCIDENT_ADDRESS      GEO_X      GEO_Y     GEO_LON    GEO_LAT  \
# 0                  NaN  3193983.0  1707251.0 -104.809881  39.773188
# 1                  NaN  3201943.0  1711852.0 -104.781434  39.785649
# 2  2932 S JOSEPHINE ST  3152762.0  1667011.0 -104.957381  39.663490
# 3  705 S COLORADO BLVD  3157162.0  1681320.0 -104.941440  39.702698
# 4       2810 E 1ST AVE  3153211.0  1686545.0 -104.955370  39.717107
#
#    DISTRICT_ID  PRECINCT_ID             NEIGHBORHOOD_ID  IS_CRIME  IS_TRAFFIC
# 0            5          521                   montbello         1           0
# 1            5          522  gateway-green-valley-ranch         1           0
# 2            3          314                   wellshire         1           0
# 3            3          312                     belcaro         1           0
# 4            3          311                cherry-creek         1           0

# %%
mask_not_crime = df_['IS_CRIME'] == 0
df_crime = df_[~mask_not_crime]
print('Crimes: {1}\t Not crimes: {0}'.format(df_[mask_not_crime].INCIDENT_ID.count(), df_crime.INCIDENT_ID.count()))
# Out:
# Crimes: 340193	 Not crimes: 119666

# %% [markdown]
# ## Initial Explorations

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459859 entries, 0 to 459858
# Data columns (total 19 columns):
# INCIDENT_ID               459859 non-null int64
# OFFENSE_ID                459859 non-null int64
# OFFENSE_CODE              459859 non-null int64
# OFFENSE_CODE_EXTENSION    459859 non-null int64
# OFFENSE_TYPE_ID           459859 non-null object
# OFFENSE_CATEGORY_ID       459859 non-null object
# FIRST_OCCURRENCE_DATE     459859 non-null datetime64[ns]
# LAST_OCCURRENCE_DATE      145591 non-null datetime64[ns]
# REPORTED_DATE             459859 non-null datetime64[ns]
# INCIDENT_ADDRESS          414636 non-null object
# GEO_X                     456120 non-null float64
# GEO_Y                     456120 non-null float64
# GEO_LON                   456120 non-null float64
# GEO_LAT                   456120 non-null float64
# DISTRICT_ID               459859 non-null int64
# PRECINCT_ID               459859 non-null int64
# NEIGHBORHOOD_ID           459859 non-null object
# IS_CRIME                  459859 non-null int64
# IS_TRAFFIC                459859 non-null int64
# dtypes: datetime64[ns](3), float64(4), int64(8), object(4)
# memory usage: 66.7+ MB

# %% [markdown]
# There are 19 columns. Last occurence date has the most null values (314268) possibly due to incomplete reporting or cases waiting to be updated or that the incident only happened once (we'll explore this a little further). Incident address has 45223 null values, of which some amount are sexual assaults since locations for these are not reported, and some may just not have a parcel address. There are 3739 null-valued GIS (GEO_X, GEO_Y, GEO_LON, GEO_LAT) entries which, again, should be inclusive of sexual assaults as their locations are not reported. All other coulmns are non-null for all entries.

# %%
df_has_last_occ = df_crime[~df_crime['LAST_OCCURRENCE_DATE'].isna()]
# df_has_last_occ['TIME_DELTA'] = df_has_last_occ['LAST_OCCURRENCE_DATE'] - df_has_last_occ['FIRST_OCCURRENCE_DATE']
df_has_last_occ = df_has_last_occ.assign(TIME_DELTA=
                                         df_has_last_occ['LAST_OCCURRENCE_DATE'] - df_has_last_occ['FIRST_OCCURRENCE_DATE'])

# %%
df_has_last_occ['TIME_DELTA'].describe()
# Out:
# count                     145210
# mean      4 days 14:35:53.389298
# std      34 days 04:48:40.249656
# min            -1 days +04:00:00
# 25%              0 days 00:22:00
# 50%              0 days 06:00:00
# 75%              0 days 15:30:00
# max           1609 days 23:00:00
# Name: TIME_DELTA, dtype: object

# %%
df_has_last_occ.loc[df_has_last_occ['TIME_DELTA'].idxmax()]
# Out:
# INCIDENT_ID                        2018669371
# OFFENSE_ID                   2018669371110900
# OFFENSE_CODE                             1109
# OFFENSE_CODE_EXTENSION                      0
# OFFENSE_TYPE_ID             sex-aslt-non-rape
# OFFENSE_CATEGORY_ID            sexual-assault
# FIRST_OCCURRENCE_DATE     2014-05-01 00:00:00
# LAST_OCCURRENCE_DATE      2018-09-26 23:00:00
# REPORTED_DATE             2018-09-29 14:27:00
# INCIDENT_ADDRESS                          NaN
# GEO_X                                     NaN
# GEO_Y                                     NaN
# GEO_LON                                   NaN
# GEO_LAT                                   NaN
# DISTRICT_ID                                 3
# PRECINCT_ID                               311
# NEIGHBORHOOD_ID                  country-club
# IS_CRIME                                    1
# IS_TRAFFIC                                  0
# TIME_DELTA                 1609 days 23:00:00
# Name: 454172, dtype: object

# %%
mask75 = df_has_last_occ['TIME_DELTA'] >= timedelta(hours=15, minutes=30)
df_has_last_occ[mask75]['TIME_DELTA'].describe()
# Out:
# count                      36453
# mean     17 days 20:06:21.441856
# std      66 days 12:36:54.211460
# min              0 days 15:30:00
# 25%              1 days 00:00:00
# 50%              2 days 01:00:00
# 75%              7 days 00:00:00
# max           1609 days 23:00:00
# Name: TIME_DELTA, dtype: object

# %%
mask25 = df_has_last_occ['TIME_DELTA'] <= timedelta(minutes=21)
df_has_last_occ[mask25]['TIME_DELTA'].describe()
# Out:
# count                     36283
# mean     0 days 00:06:14.137199
# std      0 days 00:15:10.222343
# min           -1 days +04:00:00
# 25%             0 days 00:00:00
# 50%             0 days 00:05:00
# 75%             0 days 00:10:00
# max             0 days 00:21:00
# Name: TIME_DELTA, dtype: object

# %%
maskNeg = df_has_last_occ['TIME_DELTA'] < timedelta(seconds=0)
df_has_last_occ[maskNeg]['TIME_DELTA'].describe()
# Out:
# count                          39
# mean     -1 days +20:00:41.538461
# std        0 days 05:43:32.424145
# min             -1 days +04:00:00
# 25%             -1 days +18:45:00
# 50%             -1 days +23:00:00
# 75%             -1 days +23:45:00
# max             -1 days +23:58:00
# Name: TIME_DELTA, dtype: object

# %%
df_has_last_occ[maskNeg]
# Out:
#         INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 46011    2014388104   2014388104570700          5707                       0
# 46609    2014373704   2014373704299901          2999                       1
# 52805    2014353737   2014353737299901          2999                       1
# 56134    2014399282   2014399282240400          2404                       0
# 64958    2014596887   2014596887131302          1313                       2
# 69989   20149515342  20149515342240400          2404                       0
# 102742   2015539465   2015539465240400          2404                       0
# 113677    201594326    201594326239900          2399                       0
# 124400   2015752334   2015752334570700          5707                       0
# 126545   2016151736   2016151736355000          3550                       0
# 141329   2016415601   2016415601220400          2204                       0
# 155578   2016751799   2016751799240400          2404                       0
# 168048   2017122300   2017122300240400          2404                       0
# 175369   2017115679   2017115679299900          2999                       0
# 176618    201719458    201719458220401          2204                       1
# 180146   2016820361   2016820361200600          2006                       0
# 196461   2017694591   2017694591240400          2404                       0
# 204754   2017474579   2017474579299901          2999                       1
# 241997   2014596887   2014596887109900          1099                       0
# 242340   2014656045   2014656045240400          2404                       0
# 245262  20148047026  20148047026240400          2404                       0
# 253952   2014353737   2014353737299902          2999                       2
# 258914   2014399282   2014399282353200          3532                       0
# 268612   2015752334   2015752334240400          2404                       0
# 275735    201526840    201526840549900          5499                       0
# 278421    201526819    201526819121200          1212                       0
# 292295   2016751799   2016751799549900          5499                       0
# 295554   2016415601   2016415601299900          2999                       0
# 300172   2015633506   2015633506355000          3550                       0
# 303095    201624902    201624902240400          2404                       0
# 311754   2017474579   2017474579299900          2999                       0
# 314591   2017614233   2017614233240400          2404                       0
# 315297   2017479079   2017479079549900          5499                       0
# 241997  39.658202            3          323            kennedy         1
# 242340  39.727035            1          122         villa-park         1
# 245262  39.837367            7          759                dia         1
# 253952  39.701416            4          412           westwood         1
# 258914  39.754553            6          621        five-points         1
# 268612  39.701349            4          412           westwood         1
# 275735  39.696746            4          421            mar-lee         1
# 278421  39.696746            4          421            mar-lee         1
# 292295  39.763224            1          113           highland         1
# 295554  39.793175            5          521          montbello         1
# 300172  39.738676            6          623       capitol-hill         1
# 303095  39.657232            4          423  harvey-park-south         1
# 311754  39.765911            6          612        five-points         1
# 314591  39.708288            4          412           westwood         1
# 315297  39.741067            2          223        east-colfax         1
# 347054  39.692794            4          421            mar-lee         1
# 355598  39.793175            5          521          montbello         1
# 359036  39.746545            6          611                cbd         1
# 359719  39.738676            6          623       capitol-hill         1
# 395767  39.703330            4          412           westwood         1
# 406634  39.741067            2          223        east-colfax         1
#
#         IS_TRAFFIC        TIME_DELTA
# 46011            0 -1 days +23:31:00
# 46609            0 -1 days +23:00:00
# 52805            0 -1 days +23:01:00
# 56134            0 -1 days +22:23:00
# 64958            0 -1 days +23:45:00
# 69989            0 -1 days +12:33:00
# 102742           0 -1 days +19:44:00
# 113677           0 -1 days +22:25:00
# 124400           0 -1 days +04:00:00
# 126545           0 -1 days +23:35:00
# 141329           0 -1 days +13:48:00
# 155578           0 -1 days +23:45:00
# 168048           0 -1 days +17:10:00
# 175369           0 -1 days +20:50:00
# 176618           0 -1 days +13:54:00
# 180146           0 -1 days +23:52:00
# 196461           0 -1 days +19:00:00
# 204754           0 -1 days +23:47:00
# 241997           0 -1 days +23:45:00
# 242340           0 -1 days +20:55:00
# 245262           0 -1 days +22:12:00
# 253952           0 -1 days +23:01:00
# 258914           0 -1 days +22:23:00
# 268612           0 -1 days +04:00:00
# 275735           0 -1 days +23:31:00
# 278421           0 -1 days +23:31:00
# 292295           0 -1 days +23:45:00
# 295554           0 -1 days +13:48:00
# 300172           0 -1 days +23:58:00
# 303095           0 -1 days +05:00:00
# 311754           0 -1 days +23:47:00
# 314591           0 -1 days +23:00:00
# 315297           0 -1 days +23:58:00
# 347054           0 -1 days +18:30:00
# 355598           0 -1 days +13:48:00
# 359036           0 -1 days +23:35:00
# 359719           0 -1 days +23:58:00
# 395767           0 -1 days +22:01:00
# 406634           0 -1 days +23:58:00

# %% [markdown]
# ### Missing locations and Sexual Assaults

# %%
df_no_loc = df_crime[df_crime['GEO_X'].isna()]
df_no_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3739 entries, 177 to 459566
# Data columns (total 19 columns):
# INCIDENT_ID               3739 non-null int64
# OFFENSE_ID                3739 non-null int64
# OFFENSE_CODE              3739 non-null int64
# OFFENSE_CODE_EXTENSION    3739 non-null int64
# OFFENSE_TYPE_ID           3739 non-null object
# OFFENSE_CATEGORY_ID       3739 non-null object
# FIRST_OCCURRENCE_DATE     3739 non-null datetime64[ns]
# LAST_OCCURRENCE_DATE      2205 non-null datetime64[ns]
# REPORTED_DATE             3739 non-null datetime64[ns]
# INCIDENT_ADDRESS          0 non-null object
# GEO_X                     0 non-null float64
# GEO_Y                     0 non-null float64
# GEO_LON                   0 non-null float64
# GEO_LAT                   0 non-null float64
# DISTRICT_ID               3739 non-null int64
# PRECINCT_ID               3739 non-null int64
# NEIGHBORHOOD_ID           3739 non-null object
# IS_CRIME                  3739 non-null int64
# IS_TRAFFIC                3739 non-null int64
# dtypes: datetime64[ns](3), float64(4), int64(8), object(4)
# memory usage: 584.2+ KB

# %%
df_null_loc_codes = df_offense_codes[df_offense_codes['OFFENSE_CODE'].isin(df_no_loc['OFFENSE_CODE'].unique())]
df_null_loc_codes
# Out:
#      OFFENSE_CODE  OFFENSE_CODE_EXTENSION               OFFENSE_TYPE_ID  \
# 31           3601                       1  sex-aslt-fondle-adult-victim
# 177          1102                       0                 sex-aslt-rape
# 178          1102                       1             sex-aslt-rape-pot
# 180          1109                       0             sex-aslt-non-rape
# 181          1109                       1         sex-aslt-non-rape-pot
# 188          1199                       0             sex-aslt-w-object
# 189          1199                       1         sex-aslt-w-object-pot
#
#                                      OFFENSE_TYPE_NAME OFFENSE_CATEGORY_ID  \
# 31                                Fondling of an adult      sexual-assault
# 177                                               Rape      sexual-assault
# 178            Rape by a person in a position of trust      sexual-assault
# 180                           Unlawful sexual contact       sexual-assault
# 181                            Unlawful sexual contact      sexual-assault
# 188                      Sexual assault with an object      sexual-assault
# 189  Sexual assault w/object by a person in a posit...      sexual-assault
#
#     OFFENSE_CATEGORY_NAME  IS_CRIME  IS_TRAFFIC
# 31         Sexual Assault         1           0
# 177        Sexual Assault         1           0
# 178        Sexual Assault         1           0
# 180        Sexual Assault         1           0
# 181        Sexual Assault         1           0
# 188        Sexual Assault         1           0
# 189        Sexual Assault         1           0

# %%
df_sex_codes = df_offense_codes[df_offense_codes['OFFENSE_TYPE_ID'].str.contains('sex')]
df_sex_codes
# Out:
#      OFFENSE_CODE  OFFENSE_CODE_EXTENSION                 OFFENSE_TYPE_ID  \
# 31           3601                       1    sex-aslt-fondle-adult-victim
# 33           3607                       0       sex-off-incest-with-adult
# 35           3612                       0        sex-off-fail-to-register
# 36           3613                       0       sex-off-registration-viol
# 38           3699                       0                   sex-off-other
# 106          5309                       3     harassment-sexual-in-nature
# 166          1003                       0        kidnap-minor-to-sex-aslt
# 167          1004                       0        kidnap-adult-to-sex-aslt
# 176          1101                       0                    sex-aslt-gun
# 177          1102                       0                   sex-aslt-rape
# 178          1102                       1               sex-aslt-rape-pot
# 179          1103                       0             sex-aslt-strong-arm
# 180          1109                       0               sex-aslt-non-rape
# 181          1109                       1           sex-aslt-non-rape-pot
# 182          1112                       0  sex-asslt-sodomy-boy-strng-arm
# 183          1113                       0  sex-asslt-sodomy-man-strng-arm
# 184          1114                       0  sex-asslt-sodomy-girl-strg-arm
# 185          1115                       0  sex-asslt-sodomy-woman-str-arm
# 186          1116                       0         sex-aslt-statutory-rape
# 187          1116                       1     sex-aslt-statutory-rape-pot
# 188          1199                       0               sex-aslt-w-object
# 189          1199                       1           sex-aslt-w-object-pot
#
#                                      OFFENSE_TYPE_NAME  \
# 31                                Fondling of an adult
# 33                                Incest with an adult
# 35               Failure to register as a sex offender
# 36                 Sex offender registration violation
# 38                                 Sex offense - other
# 106                      Harassment - sexual in nature
# 166                   Kidnap minor to sexually assault
# 167                   Kidnap adult to sexually assault
# 176                        Rape, perpetrator had a gun
# 177                                               Rape
# 178            Rape by a person in a position of trust
# 179                  Rape using the threat of violence
# 180                           Unlawful sexual contact
# 181                            Unlawful sexual contact
# 182       Sodomy of a male juvenile using bodily force
# 183         Sodomy of an adult male using bodily force
# 184     Sodomy of a female juvenile using bodily force
# 185       Sodomy of an adult female using bodily force
# 186                                     Statutory rape
# 187  Statutory rape by a person in a position of trust
# 188                      Sexual assault with an object
# 189  Sexual assault w/object by a person in a posit...
#
#               OFFENSE_CATEGORY_ID         OFFENSE_CATEGORY_NAME  IS_CRIME  \
# 31                 sexual-assault                Sexual Assault         1
# 33   other-crimes-against-persons  Other Crimes Against Persons         1
# 35               all-other-crimes              All Other Crimes         1
# 36               all-other-crimes              All Other Crimes         1
# 38   other-crimes-against-persons  Other Crimes Against Persons         1
# 106               public-disorder               Public Disorder         1
# 166              all-other-crimes              All Other Crimes         1
# 167              all-other-crimes              All Other Crimes         1
# 176                sexual-assault                Sexual Assault         1
# 177                sexual-assault                Sexual Assault         1
# 178                sexual-assault                Sexual Assault         1
# 179                sexual-assault                Sexual Assault         1
# 180                sexual-assault                Sexual Assault         1
# 181                sexual-assault                Sexual Assault         1
# 182                sexual-assault                Sexual Assault         1
# 183                sexual-assault                Sexual Assault         1
# 184                sexual-assault                Sexual Assault         1
# 185                sexual-assault                Sexual Assault         1
# 186  other-crimes-against-persons  Other Crimes Against Persons         1
# 187  other-crimes-against-persons  Other Crimes Against Persons         1
# 188                sexual-assault                Sexual Assault         1
# 189                sexual-assault                Sexual Assault         1
#
#      IS_TRAFFIC
# 31            0
# 33            0
# 35            0
# 36            0
# 38            0
# 106           0
# 166           0
# 167           0
# 176           0
# 177           0
# 178           0
# 179           0
# 180           0
# 181           0
# 182           0
# 183           0
# 184           0
# 185           0
# 186           0
# 187           0
# 188           0
# 189           0

# %% [markdown]
# Not all sexual crime codes were contained within the null-valued location offenses. Are the codes not in this subset used in the database?

# %%
df_sex_notin = df_sex_codes[~df_sex_codes['OFFENSE_CODE'].isin(df_null_loc_codes['OFFENSE_CODE'])]

# %%
df_crime[df_crime['OFFENSE_CODE'].isin(df_sex_notin['OFFENSE_CODE'])].groupby('OFFENSE_CODE').count()
# Out:
#               INCIDENT_ID  OFFENSE_ID  OFFENSE_CODE_EXTENSION  \
# OFFENSE_CODE
# 3612                 1305        1305                    1305
# 3613                   82          82                      82
# 5309                 1854        1854                    1854
#
#               OFFENSE_TYPE_ID  OFFENSE_CATEGORY_ID  FIRST_OCCURRENCE_DATE  \
# OFFENSE_CODE
# 3612                     1305                 1305                   1305
# 3613                       82                   82                     82
# 5309                     1854                 1854                   1854
#
#               LAST_OCCURRENCE_DATE  REPORTED_DATE  INCIDENT_ADDRESS  GEO_X  \
# OFFENSE_CODE
# 3612                           316           1305              1296   1305
# 3613                             3             82                82     82
# 5309                           982           1854              1294   1854
#
#               GEO_Y  GEO_LON  GEO_LAT  DISTRICT_ID  PRECINCT_ID  \
# OFFENSE_CODE
# 3612           1305     1305     1305         1305         1305
# 3613             82       82       82           82           82
# 5309           1854     1854     1854         1854         1854
#
#               NEIGHBORHOOD_ID  IS_CRIME  IS_TRAFFIC
# OFFENSE_CODE
# 3612                     1305      1305        1305
# 3613                       82        82          82
# 5309                     1854      1854        1854

# %%
mask_sex_loc = df_crime[df_crime['OFFENSE_CODE'].isin(df_sex_notin['OFFENSE_CODE'])].groupby('OFFENSE_CODE')['OFFENSE_CODE'].unique()
df_offense_codes[df_offense_codes['OFFENSE_CODE'].isin(mask_sex_loc)]
# Out:
#      OFFENSE_CODE  OFFENSE_CODE_EXTENSION              OFFENSE_TYPE_ID  \
# 35           3612                       0     sex-off-fail-to-register
# 36           3613                       0    sex-off-registration-viol
# 103          5309                       0                   harassment
# 104          5309                       1                harassment-dv
# 105          5309                       2           harassment-obscene
# 106          5309                       3  harassment-sexual-in-nature
#
#                          OFFENSE_TYPE_NAME OFFENSE_CATEGORY_ID  \
# 35   Failure to register as a sex offender    all-other-crimes
# 36     Sex offender registration violation    all-other-crimes
# 103                             Harassment     public-disorder
# 104                        Harassment - DV     public-disorder
# 105                     Obscene harassment     public-disorder
# 106          Harassment - sexual in nature     public-disorder
#
#     OFFENSE_CATEGORY_NAME  IS_CRIME  IS_TRAFFIC
# 35       All Other Crimes         1           0
# 36       All Other Crimes         1           0
# 103       Public Disorder         1           0
# 104       Public Disorder         1           0
# 105       Public Disorder         1           0
# 106       Public Disorder         1           0

# %% [markdown]
# No sexual assaults have locations included. However, locations for sexual harassment and sex offenders failing to register are present in the database.

# %% [markdown]
# ## What crimes are most frequent?
#
# ### How many different types of crimes are represented here?

# %%
len(df_crime['OFFENSE_TYPE_ID'].unique())
# Out:
# 195

# %% [markdown]
# ### Crime totals by category

# %%
df_crime.groupby('OFFENSE_CATEGORY_ID')['OFFENSE_CATEGORY_ID'].count()
# Out:
# OFFENSE_CATEGORY_ID
# aggravated-assault              10731
# all-other-crimes                84195
# arson                             576
# auto-theft                      24159
# burglary                        22900
# drug-alcohol                    30678
# larceny                         46174
# murder                            261
# other-crimes-against-persons    22363
# public-disorder                 48290
# robbery                          5957
# sexual-assault                   3739
# theft-from-motor-vehicle        34010
# white-collar-crime               6160
# Name: OFFENSE_CATEGORY_ID, dtype: int64

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,8))

df_category = df_crime[~mask_not_crime].groupby('OFFENSE_CATEGORY_ID')
df_category['OFFENSE_CATEGORY_ID'].count().plot(kind='bar', ax=ax1)
ax1.set_title('Total Crimes by category')

df_crime[df_crime['OFFENSE_CATEGORY_ID'] == 'all-other-crimes'
        ].groupby('OFFENSE_TYPE_ID')['OFFENSE_TYPE_ID'].count().plot(kind='bar', ax=ax2)
ax2.set_title('Crimes under all-other-crimes')

figs_save['Total crimes by category'] = (fig, 'tot_crime_categ.jpg')
# Out:
# /home/mosqueteiro/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/mosqueteiro/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df_crime[df_crime['OFFENSE_CATEGORY_ID'] == 'all-other-crimes'].groupby('OFFENSE_TYPE_ID')['OFFENSE_TYPE_ID'].count()
# Out:
# OFFENSE_TYPE_ID
# accessory-conspiracy-to-crime       136
# agg-aslt-police-weapon              293
# animal-cruelty-to                   125
# animal-poss-of-dangerous             14
# aslt-agg-police-gun                   7
# bomb-threat                         159
# bribery                              20
# contraband-into-prison              273
# contraband-possession                55
# criminal-trespassing              13989
# disarming-a-peace-officer            27
# eavesdropping                         2
# escape                              135
# escape-aiding                         4
# explosive-incendiary-dev-pos         33
# explosive-incendiary-dev-use         14
# explosives-posses                     1
# extortion                            92
# failure-to-appear                   308
# failure-to-report-abuse               3
# false-imprisonment                  365
# fireworks-possession                158
# gambling-device                       4
# gambling-gaming-operation            10
# homicide-conspiracy                   1
# illegal-dumping                     118
# intimidation-of-a-witness           133
# kidnap-adult-victim                 210
# kidnap-dv                           162
# littering                           145
#                                   ...
# police-obstruct-investigation        25
# police-resisting-arrest             738
# probation-violation                  25
# property-crimes-other               207
# pub-peace-desecrate-symb              2
# public-fighting                     852
# public-order-crimes-other          7489
# reckless-endangerment               149
# sex-off-fail-to-register           1305
# sex-off-registration-viol            82
# stolen-property-buy-sell-rec        143
# traf-habitual-offender             3581
# traf-impound-vehicle                 18
# traf-other                        30968
# traf-vehicular-assault              219
# vehicular-eluding                   213
# vehicular-eluding-no-chase         3409
# violation-of-court-order           2513
# violation-of-custody-order           57
# violation-of-restraining-order     2780
# weapon-altering-serial-number        26
# weapon-by-prev-offender-powpo      1379
# weapon-carrying-concealed           457
# weapon-carrying-prohibited          427
# weapon-flourishing                  260
# weapon-other-viol                   747
# weapon-poss-illegal-dangerous       739
# weapon-unlawful-discharge-of       2193
# weapon-unlawful-sale                  2
# wiretapping                           6
# Name: OFFENSE_TYPE_ID, Length: 69, dtype: int64

# %% [markdown]
# ### By district

# %%
districts = sorted(df_crime['DISTRICT_ID'].unique())
# df_districts = df_crime.groupby(['OFFENSE_CATEGORY_ID', 'DISTRICT_ID'])

# df_districts['DISTRICT_ID'].count().plot(kind='bar', subplots=True)
# df_category[df_category['DISTRICT_ID'] == 1].head()
# df_districts.columns
# df_category[df_category['DISTRICT_ID'] == 1]['OFFENSE_CATEGORY_ID'].count().plot(kind='bar')

fig, axes = plt.subplots(len(districts),1, figsize=(10,40))

for district in districts:
    df_crime[df_crime['DISTRICT_ID'] == district
            ].groupby('OFFENSE_CATEGORY_ID')['OFFENSE_CATEGORY_ID'].count().plot(kind='bar', ax=axes[district-1])
    axes[district-1].set_title(f'District {district}: Crime by type')
fig.tight_layout()

figs_save['District crime by type'] = (fig, 'dist_crime_by_type.jpg')

# %%
fig1, ax = plt.subplots(figsize=(50,70))
dist_colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink']
# dist_leg = pd.DataFrame([x for x in zip(range(1,8), dist_colors)])
dist_colors = dist_colors*2 + ['blue', 'orange', 'green', 'red', 'purple', 'brown'] + dist_colors*11
df_crime.groupby(['OFFENSE_CATEGORY_ID', 'DISTRICT_ID']
                ).INCIDENT_ID.count().plot(kind='bar', fontsize=10, color=dist_colors, ax=ax)
# pd.plotting.table(ax, dist_leg, loc='upper right')

figs_save['Crime by category and district'] = (fig1, 'crime_categ_dist.jpg')

# %% [markdown]
# ## Time series

# %%
oldest_date = df_crime['FIRST_OCCURRENCE_DATE'].min()
newest_date = df_crime['FIRST_OCCURRENCE_DATE'].max()
newest_date
# Out:
# Timestamp('2019-02-11 07:35:00')

# %%
mask2019 = df_crime['FIRST_OCCURRENCE_DATE'] > datetime(year=2018, month=12, day=31, hour=23, minute=59, second=59)
df_crime[~mask2019].FIRST_OCCURRENCE_DATE.max()
# Out:
# Timestamp('2018-12-31 23:59:00')

# %%
df_crime[~mask2019].groupby([df_crime.FIRST_OCCURRENCE_DATE.dt.year, df_crime.FIRST_OCCURRENCE_DATE.dt.month]
                )['INCIDENT_ID'].count()
# Out:
# FIRST_OCCURRENCE_DATE  FIRST_OCCURRENCE_DATE
# 2014                   1                        4271
#                        2                        4222
#                        3                        5193
#                        4                        5029
#                        5                        5440
#                        6                        5450
#                        7                        5709
#                        8                        5936
#                        9                        5684
#                        10                       5635
#                        11                       4655
#                        12                       4762
# 2015                   1                        5352
#                        2                        4337
#                        3                        5331
#                        4                        5614
#                        5                        5646
#                        6                        5717
#                        7                        6088
#                        8                        6045
#                        9                        5753
#                        10                       6016
#                        11                       5109
#                        12                       5031
# 2016                   1                        5715
#                        2                        5179
#                        3                        5532
#                        4                        5868
#                        5                        6020
#                        6                        5709
#                        7                        5656
#                        8                        5954
#                        9                        5914
#                        10                       5962
#                        11                       5074
#                        12                       5049
# 2017                   1                        5589
#                        2                        5043
#                        3                        5769
#                        4                        5611
#                        5                        5955
#                        6                        6076
#                        7                        6059
#                        8                        6561
#                        9                        5914
#                        10                       5814
#                        11                       5392
#                        12                       5108
# 2018                   1                        5763
#                        2                        4918
#                        3                        5593
#                        4                        5938
#                        5                        6237
#                        6                        5825
#                        7                        6313
#                        8                        6361
#                        9                        6063
#                        10                       5707
#                        11                       5121
#                        12                       5054
# Name: INCIDENT_ID, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(11,6))
df_crime[~mask2019].groupby([df_crime.FIRST_OCCURRENCE_DATE.dt.year, df_crime.FIRST_OCCURRENCE_DATE.dt.month]
                )['INCIDENT_ID'].count().unstack(0).plot(xticks=range(1,13), ax=ax)

ax.set_title('Crimes per month')
ax.set_xlabel('Month')
ax.set_ylabel('Crime count')
ax.legend(loc='upper right')

figs_save['Crime over years'] = (fig_year_month, 'crime_year.jpg')

# %%
fig, ax = plt.subplots(figsize=(11,6))
# df_crime[~mask2019].groupby(df_crime.FIRST_OCCURRENCE_DATE.dt.date).INCIDENT_ID.count().plot(kind='line', ax=ax)
date_counts = df_crime[~mask2019].FIRST_OCCURRENCE_DATE.dt.date.value_counts().sort_index()
date_counts.plot(ax=ax, label='Daily crime count')
date_counts.ewm(alpha=0.05).mean().plot(ax=ax, label='Exponential rolling mean')

ax.legend(loc='lower right')
ax.set_xlabel('Year')
ax.set_ylabel('Number of crimes')
ax.set_title('Crimes per day: 2014 - 2018')

figs_save['Crimes per day: 2014 - 2018'] = (fig, 'crime_daily_alltime.jpg')

# %%
date_counts.rolling(100).mean().tail()
# Out:
# 2018-07-20    231.67
# 2017-08-18    231.98
# 2014-08-01    232.30
# 2018-05-01    232.62
# 2017-01-01    232.98
# Name: FIRST_OCCURRENCE_DATE, dtype: float64

# %% [markdown]
# df_crime.groupby('OFFENSE_CATEGORY_ID')['OFFENSE_CATEGORY_ID'].count()

# %% [markdown]
# ## Save all specified figures

# %%
for fig, name in figs_save.values():
    fig.savefig('images/'+name)
